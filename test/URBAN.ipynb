# %%
from aip import AipImageClassify
import matplotlib.image as imgplot
import matplotlib.pyplot as plot
APP_ID = '19147852'

API_KEY = 'zYyAsv8vuOt14xW4uekUynXY'

SECRET_KEY = '93YSsTaG9r2GGVYtbVi7jr51XVjVomfB'

分类器 = AipImageClassify(APP_ID, API_KEY, SECRET_KEY)

filePath1 = "C:\\Users\\chenh\\Desktop\\test\\tulipe.jpg"

def get_file_content(filePath1):
    with open(filePath1, 'rb') as fp:
        return fp.read()

options = {}
options["top_num"] = 5 
result=分类器.plantDetect(get_file_content(filePath1),options)

print(result)
# Out:
# {'log_id': 1290771255451457245, 'result': [{'score': 0.7964872121810913, 'name': '郁金香'}, {'score': 0.0473126582801342, 'name': '网球花'}, {'score': 0.0123065747320652, 'name': '鸢尾'}, {'score': 0.005430995021015406, 'name': '郁金'}, {'score': 0.0037930933758616447, 'name': '伊犁郁金香'}]}

# %%
x = imgplot.imread('C:\\Users\\chenh\\Desktop\\test\\tulipe.jpg')
plot.imshow(x)

# %%
filePath2 = "C:\\Users\\chenh\\Desktop\\test\\BOUGAINVILLEA.jpg"

def get_file_content(filePath2):
    with open(filePath2, 'rb') as fp:
        return fp.read()

options = {}
options["top_num"] = 5 
result=分类器.plantDetect(get_file_content(filePath2),options)

print(result)
# Out:
# {'log_id': 691698141753497437, 'result': [{'score': 0.7785916328430176, 'name': '叶子花'}, {'score': 0.12489022314548492, 'name': '光叶子花'}, {'score': 0.002750811167061329, 'name': '紫茉莉'}, {'score': 0.0022723558358848095, 'name': '杜鹃'}, {'score': 0.002039901912212372, 'name': '碧冬茄'}]}

# %%
x = imgplot.imread('C:\\Users\\chenh\\Desktop\\test\\BOUGAINVILLEA.jpg')
plot.imshow(x)

# %%
filePath3 = "C:\\Users\\chenh\\Desktop\\test\\AZALEA.jpg"

def get_file_content(filePath3):
    with open(filePath3, 'rb') as fp:
        return fp.read()

options = {}
options["top_num"] = 5 
result=分类器.plantDetect(get_file_content(filePath3),options)

print(result)
# Out:
# {'log_id': 8728480472409210941, 'result': [{'score': 0.6809239387512207, 'name': '杜鹃花'}, {'score': 0.48308438062667847, 'name': '杜鹃'}, {'score': 0.08711797744035721, 'name': '锦绣杜鹃'}, {'score': 0.03413162752985954, 'name': '迎红杜鹃'}, {'score': 0.022168252617120743, 'name': '满山红'}]}

# %%
x = imgplot.imread('C:\\Users\\chenh\\Desktop\\test\\AZALEA.jpg')
plot.imshow(x)

# %%
filePath4 = "C:\\Users\\chenh\\Desktop\\test\\UNKNOWN1.jpg"

def get_file_content(filePath4):
    with open(filePath4, 'rb') as fp:
        return fp.read()

options = {}
options["top_num"] = 5 
result=分类器.plantDetect(get_file_content(filePath4),options)

print(result)
x = imgplot.imread('C:\\Users\\chenh\\Desktop\\test\\UNKNOWN1.jpg')
plot.imshow(x)
# Out:
# {'log_id': 1378133712527719133, 'result': [{'score': 0.8652070760726929, 'name': '紫藤'}, {'score': 0.04296845570206642, 'name': '多花紫藤'}, {'score': 0.007752120960503817, 'name': '藤萝'}, {'score': 0.0017155290115624666, 'name': '常春油麻藤'}, {'score': 0.0016943014925345778, 'name': '蜡梅'}]}

# %%
filePath5 = "C:\\Users\\chenh\\Desktop\\test\\UNKNOWN2.jpg"

def get_file_content(filePath5):
    with open(filePath5, 'rb') as fp:
        return fp.read()

options = {}
options["top_num"] = 5 
result=分类器.plantDetect(get_file_content(filePath5),options)

print(result)
x = imgplot.imread('C:\\Users\\chenh\\Desktop\\test\\UNKNOWN2.jpg')
plot.imshow(x)
# Out:
# {'log_id': 1394095707282150141, 'result': [{'score': 0.2831266522407532, 'name': '心叶日中花'}, {'score': 0.13525334000587463, 'name': '绣球花'}, {'score': 0.11062324792146683, 'name': '花叶蔓长春花'}, {'score': 0.07584352791309357, 'name': '银边翠'}, {'score': 0.07070136070251465, 'name': '红雀珊瑚'}]}
