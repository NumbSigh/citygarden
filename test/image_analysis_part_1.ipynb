# %%
import numpy as np
import matplotlib.pyplot as plt
# im = plt.imread(r"\\pcpool.rz.rwth-aachen.de\files\home\tz053471\Desktop\Numerical\111.jpg")
# import image from another folder

# %%
from scipy import ndimage
im = ndimage.imread("111.jpg")

# %%
# %matplotlib inline

# %%
im = ndimage.imread("111.jpg", mode = "I")

# %%
im.shape
# Out:
# (961, 960)

# %%
im
# Out:
# array([[206, 190, 186, ..., 136, 157, 196],
#        [168, 198, 199, ..., 159, 162, 175],
#        [167, 175, 190, ..., 176, 138, 130],
#        ...,
#        [149, 169, 191, ..., 170, 166, 143],
#        [155, 169, 170, ..., 193, 163, 141],
#        [199, 179, 160, ..., 171, 146, 141]])

# %%
import numpy as np
n_random_points = 1000

# %%
y_max, x_max = im.shape
x_random = np.random.randint(0,x_max,n_random_points)
y_random = np.random.randint(0,y_max,n_random_points)
training_vals = np.random.randint(0,961)

# %%
fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(111)
ax.imshow(im,cmap = "gray", origin='lower left')
ax.plot(x_random,y_random,'s')
ax.set_xlim((0,im.shape[1]))
ax.set_ylim((0,im.shape[0]))
# plt.favefig("image_and_points.sps", bbox_inches'tight')
# Out:
# (0, 961)

# %%
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111)
scat = ax.scatter(x_random,y_random, c = training_vals, cmap='viridis')
plt.colorbar(scat)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-a0f6513fd9f8> in <module>()
#       1 fig = plt.figure(figsize=(6,6))
#       2 ax = fig.add_subplot(111)
# ----> 3 scat = ax.scatter(x_random,y_random, c=training_vals, cmap='viridis')
#       4 plt.colorbar(scat)
#
# NameError: name 'training_vals' is not defined

# %%
x_random[:10], y_random[:10], training_vals[:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-30e50d6ecb7c> in <module>()
# ----> 1 x_random[:10], y_random[:10], training_vals[:10]
#
# NameError: name 'training_vals' is not defined

# %%
pos = 0
h = np.empty(n_random_points)
gamma = np.empty(n_random_points)
for i in range(n_random_points):
    #calculate gamma 
    #calculate h

# %%
    #task:plot dissimilarities
    #idea:use distance function between one and all:

# %%
h = distant[:,0]
ids = np.where((h > 500) * (h < 550))

# %%
a = np.array([True, False, True])
b = np.array([True, False, False])
np.where(a * b)

# %%
(array([0]),)

# %%
ids

# %%
gamma(np.where((h > 500) * (h < 550)))

# %%
ids = np.where((h > 500) * (h < 550))

# %%
a = np.array([True, False, True])
b = np.array([True, False, False])
a + b

# %%
ids

# %% [markdown]
# # sperical variogram

# %%
np.sperical?
# Out:
# Object `np.sperical` not found.

# %%
def sperical_variogram(h, a=1, b=1):
    if a > h :
        return b*(1.5*(h/a)-0.5*(h/a)**3)
    else:
        return b

# %%
np.exp?

# %%
def exponential_variogramm(h, a=1, b=1):
    exponential_variogramm = b*(1-exp(-3h/a))

# %%
def abc(d):
    if d > 2:
        return 2
    else:
        return 1

# %%
abc(100)
# Out:
# 2

# %%
hvals = range(0,9,1)

# %%
abc_vectorized = np.vectorize(abc)

# %%
abc_vectorized(hvals)
# Out:
# array([1, 1, 1, 2, 2, 2, 2, 2, 2])

# %% [markdown]
# # Automatic fit # Python definded best regression algorithm to fit the values

# %%
from scipy.optimize import curve_fit

# %% [markdown]
# the method curve_fit takes the function name as an input, as well as x and y data. note that, in addition, a suitable initial guess can be provided with the keyword p0 (see the help function for more infos)

# %%
popt, pcov = curve_fit(exponential_variogram,
                      h_steps, gamm_ave, p0 =(20,400))
print("the determined values are: a = %.2f (range), b = %.2f(sill)"% (popt))

# %%
curve_fit?
# Out:
# Object `curve_fit` not found.

# %% [markdown]
# creat a plot with the fitted variogram

# %%
# range 
a = popt[0]
# sill
b= popt[1]
